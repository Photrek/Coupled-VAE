# %%
# prerequisites
import numpy as np
import math as m
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Lambda, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from keras import objectives
from scipy.stats import norm
# Out:
# Using TensorFlow backend.

# %%
# data load
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr, x_te = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)
print(x_tr.shape, x_te.shape)

# network parameters
batch_size, n_epoch = 100, 60
n_hidden, z_dim = 1024, 2
# Out:
# (60000, 784) (10000, 784)

# %%
# encoder
# Initializer imported from Cao code.  May do tuning here.
initializer = tf.keras.initializers.VarianceScaling(
scale=0.1, mode='fan_in', distribution='uniform')

# Activation functions require elu followed by tanh.
x = Input(shape=(x_tr.shape[1:]))
x_encoded = Dense(n_hidden, activation='elu', kernel_initializer=initializer)(x)
x_encoded = Dropout(0.1)(x_encoded)
x_encoded = Dense(n_hidden//2, activation='elu', kernel_initializer=initializer)(x_encoded)
x_encoded = Dropout(0.1)(x_encoded)
x_encoded = Dense(n_hidden//4, activation='tanh', kernel_initializer=initializer)(x_encoded)
x_encoded = Dropout(0.1)(x_encoded)

mean_calc = Dense(z_dim, kernel_initializer=initializer)(x_encoded)

#### Rename log_var to log_stddev
log_stddev = Dense(z_dim, kernel_initializer=initializer)(x_encoded)

# Stddev initially is log.  It gets called as an exponential when being sampled.
stddev_calc = 0.000001 + (log_stddev)

# %%
# sampling function.  Function names have been cleaned up.
def sampling(args):
    mean_calc, stddev_calc = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mean_calc + K.exp(stddev_calc) * eps

z = Lambda(sampling, output_shape=(z_dim,))([mean_calc, stddev_calc])
#### Modify this part to sample from coupled gaussians instead of gaussians.

# %%
# decoder.  Following convention from Cao code, it has VarianceScaling, along with activation functions tanh,
# elu, and sigmoid.  Also imported dropout following convention.
initializer = tf.keras.initializers.VarianceScaling(
scale=0.1, mode='fan_in', distribution='uniform')

z_decoder0 = Dense(n_hidden//4, activation='tanh', kernel_initializer=initializer)
z_decoder1 = Dense(n_hidden//2, activation='elu', kernel_initializer=initializer)
z_decoder2 = Dense(n_hidden, activation='elu', kernel_initializer=initializer)
y_decoder = Dense(x_tr.shape[1], activation='sigmoid', kernel_initializer=initializer)

z_decoded = z_decoder0(z)
z_decoded = Dropout(0.1)(z_decoded)
z_decoded = z_decoder1(z_decoded)
z_decoded = Dropout(0.1)(z_decoded)
z_decoded = z_decoder2(z_decoded)
z_decoded = Dropout(0.1)(z_decoded)
y = y_decoder(z_decoded)
y = tf.clip_by_value(y, 1e-8, 1 - 1e-8)

# %%
#### Latent loss and image loss for Coupled VAE.
k = 0.225
d = 20
d1 = 1 + d * k + 2 * k
marginal_likelihood = tf.reduce_sum(x * tf.subtract(tf.pow(y, (2 * k) / (1 + k)), 1) / (2 * k) + (1 - x)
                                    * tf.subtract(tf.pow(1 - y, (2 * k) / (1 + k)), 1) / (k * 2), 1)
KL_d1 = tf.reduce_prod(tf.pow(2 * tf.constant(m.pi), k / (1 + d * k)) * tf.sqrt(d1 / (d1 - 2 * k * tf.square(stddev_calc)))
                       * tf.exp(tf.square(mean_calc) * d1 * k / (1 + d * k) / (d1 - 2 * k * tf.square(stddev_calc))), 1)
KL_d2 = tf.reduce_prod(tf.pow(2 * tf.constant(m.pi) * tf.square(stddev_calc),
                              k / (1 + k * d)) * tf.sqrt(d1 / (1 + d * k)), 1)
KL_divergence = (KL_d1 - KL_d2) / k / 2
ml = marginal_likelihood
marginal_likelihood = tf.reduce_mean(marginal_likelihood)

# %%
# loss
#reconstruction_loss = objectives.binary_crossentropy(x, y) * x_tr.shape[1]
#kl_loss = 0.5 * K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
ELBO = marginal_likelihood - KL_divergence
vae_loss = -ELBO

#vae_loss = reconstruction_loss + kl_loss

# build model
vae = Model(x, y)
vae.add_loss(vae_loss)
opt = keras.optimizers.Adam(learning_rate=1e-4)
vae.compile(optimizer=opt)
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         803840      input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            514         dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            514         dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 2)]          0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (100, 2)             0           dense_3[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (100, 256)           768         lambda[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (100, 256)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (100, 512)           131584      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (100, 512)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (100, 1024)          525312      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (100, 1024)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (100, 784)           803600      dropout_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum (TensorFlow [(100, 784)]         0           dense_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum (TensorFlow [(100, 784)]         0           tf_op_layer_Minimum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 2)]          0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(None, 2)]          0           dense_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Square[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_4 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_2 (TensorFlo [(None, 2)]          0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_5 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Square_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_2 (TensorFl [(None, 2)]          0           tf_op_layer_Sub_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_3 (TensorFl [(None, 2)]          0           tf_op_layer_Mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_5 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_3 (TensorFlo [(None, 2)]          0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pow (TensorFlowOpLa [(100, 784)]         0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pow_1 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Sub_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 2)]          0           tf_op_layer_RealDiv_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_4 (TensorFl [(None, 2)]          0           tf_op_layer_RealDiv_3[0][0]
#                                                                  tf_op_layer_Sub_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_8 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Square_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(100, 784)]         0           tf_op_layer_Pow[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1 (TensorFlowOp [(None, 784)]        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Pow_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 2)]          0           tf_op_layer_RealDiv_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pow_2 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(100, 784)]         0           input_1[0][0]
#                                                                  tf_op_layer_Sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Sub_1[0][0]
#                                                                  tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_7 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Mul_3[0][0]
#                                                                  tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_9 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Pow_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(100, 784)]         0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(100, 784)]         0           tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Prod (TensorFlowOpL [(None,)]            0           tf_op_layer_Mul_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Prod_1 (TensorFlowO [(None,)]            0           tf_op_layer_Mul_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(100, 784)]         0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_6 (TensorFlowOp [(None,)]            0           tf_op_layer_Prod[0][0]
#                                                                  tf_op_layer_Prod_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(100,)]             0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_5 (TensorFl [(None,)]            0           tf_op_layer_Sub_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [()]                 0           tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_6 (TensorFl [(None,)]            0           tf_op_layer_RealDiv_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_7 (TensorFlowOp [(None,)]            0           tf_op_layer_Mean[0][0]
#                                                                  tf_op_layer_RealDiv_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg (TensorFlowOpLa [(None,)]            0           tf_op_layer_Sub_7[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              (None,)              0           tf_op_layer_Neg[0][0]
# ==================================================================================================
# Total params: 2,922,260
# Trainable params: 2,922,260
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train
vae.fit(x_tr,
       shuffle=True,
       epochs=n_epoch,
       batch_size=batch_size,
       validation_data=(x_te, None), verbose=1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0804 12:32:25.359941 4472690112 deprecation.py:323] From /Users/danielsvoboda/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:297: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
# Epoch 1/60
# 600/600 [==============================] - 14s 24ms/step - loss: 151.9825 - val_loss: 125.9299
# Epoch 2/60
# 600/600 [==============================] - 14s 23ms/step - loss: 122.9560 - val_loss: 117.0420
# Epoch 3/60
# 600/600 [==============================] - 14s 23ms/step - loss: 116.4708 - val_loss: 113.3467
# Epoch 4/60
# 600/600 [==============================] - 14s 23ms/step - loss: 113.8244 - val_loss: 111.1054
# Epoch 5/60
# 600/600 [==============================] - 14s 23ms/step - loss: 112.0150 - val_loss: 109.1895
# Epoch 6/60
# 600/600 [==============================] - 14s 24ms/step - loss: 110.4240 - val_loss: 107.6413
# Epoch 7/60
# 600/600 [==============================] - 15s 24ms/step - loss: 108.8926 - val_loss: 106.3731
# Epoch 8/60
# 600/600 [==============================] - 14s 23ms/step - loss: 107.3909 - val_loss: 104.7321
# Epoch 9/60
# 600/600 [==============================] - 14s 23ms/step - loss: 106.0755 - val_loss: 103.4953
# Epoch 10/60
# 600/600 [==============================] - 14s 23ms/step - loss: 104.7335 - val_loss: 102.2461
# Epoch 11/60
# 600/600 [==============================] - 14s 23ms/step - loss: 103.6045 - val_loss: 101.1602
# Epoch 41/60
# 600/600 [==============================] - 14s 24ms/step - loss: 94.8898 - val_loss: 92.4075
# Epoch 42/60
# 600/600 [==============================] - 14s 24ms/step - loss: 94.8304 - val_loss: 92.1192
# Epoch 43/60
# 600/600 [==============================] - 14s 24ms/step - loss: 94.6668 - val_loss: 91.9716
# Epoch 44/60
# 600/600 [==============================] - 14s 24ms/step - loss: 94.5948 - val_loss: 91.8653
# Epoch 45/60
# 600/600 [==============================] - 14s 23ms/step - loss: 94.5294 - val_loss: 91.9197
# Epoch 46/60
# 600/600 [==============================] - 14s 23ms/step - loss: 94.4822 - val_loss: 92.0309
# Epoch 47/60
# 600/600 [==============================] - 14s 23ms/step - loss: 94.4398 - val_loss: 91.8338
# Epoch 48/60
# 600/600 [==============================] - 14s 23ms/step - loss: 94.3592 - val_loss: 91.7315
# Epoch 49/60
# 600/600 [==============================] - 13s 22ms/step - loss: 94.3156 - val_loss: 91.6138
# Epoch 50/60
# 600/600 [==============================] - 59s 98ms/step - loss: 94.1726 - val_loss: 91.8576
# Epoch 51/60
# 600/600 [==============================] - 14s 24ms/step - loss: 94.1278 - val_loss: 91.5685
# Epoch 52/60
# 600/600 [==============================] - 14s 23ms/step - loss: 94.0129 - val_loss: 91.4166
# Epoch 53/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.9619 - val_loss: 91.4192
# Epoch 54/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.9789 - val_loss: 91.4483
# Epoch 55/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.8861 - val_loss: 91.3676
# Epoch 56/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.8244 - val_loss: 91.3225
# Epoch 57/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.8086 - val_loss: 91.5239
# Epoch 58/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.7713 - val_loss: 91.2004
# Epoch 59/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.6836 - val_loss: 91.1893
# Epoch 60/60
# 600/600 [==============================] - 14s 24ms/step - loss: 93.6669 - val_loss: 91.1532

# %%
# build encoder
encoder = Model(x, mean_calc)
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              803840
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 1,460,482
# Trainable params: 1,460,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot of the digit classes in the latent space
x_te_latent = encoder.predict(x_te, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te)
plt.colorbar()
plt.show()

# %%
# build decoder
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder0(decoder_input)
_z_decoded = z_decoder1(_z_decoded)
_z_decoded = z_decoder2(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_5 (Dense)              multiple                  768
# _________________________________________________________________
# dense_6 (Dense)              multiple                  131584
# _________________________________________________________________
# dense_7 (Dense)              multiple                  525312
# _________________________________________________________________
# dense_8 (Dense)              multiple                  803600
# =================================================================
# Total params: 1,461,264
# Trainable params: 1,461,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
# display a 2D manifold of the digits
n = 15 # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
